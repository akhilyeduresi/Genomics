# %%
#Data loading
import pandas as pd

#Data visualizations
import matplotlib.pyplot as plt
import seaborn as sns

from numpy import mean

# %%
pd.read_excel('OmicsData_total.xlsx')
# Out:
#        GPOL ID  TMA ID    Chr  Feature  pSTAT3_705  a0cd1ncd2     Score
# 0     G0646L01     380  chr14     AKT1         0.0        1.0 -0.654972
# 1     G0646L01     380  chr19     AKT2         0.0        1.0 -0.056330
# 2     G0646L01     380   chr1     AKT3         0.0        1.0 -0.093635
# 3     G0646L01     380   chr2      ALK         0.0        1.0 -0.196039
# 4     G0646L01     380  chr17  ALOX12B         0.0        1.0 -0.033452
# ...        ...     ...    ...      ...         ...        ...       ...
# 7304  G0178L01     617  chr17     TP53         0.0        0.0 -0.881593
# 7305  G0185L01     718  chr13      RB1         1.0        1.0 -0.699564
# 7306  G0185L01     718  chr17     TP53         1.0        1.0 -1.093632
# 7307  G0185L01     718   chr8      MYC         1.0        1.0  1.234458
# 7308  G0187L01     682  chr18    SMAD4         0.0        2.0 -0.621177
#
# [7309 rows x 7 columns]

# %%
dfsorted1=pd.read_excel('OmicsData_total.xlsx')
dfsorted1.head(5)
# Out:
#     GPOL ID  TMA ID    Chr  Feature  pSTAT3_705  a0cd1ncd2     Score
# 0  G0646L01     380  chr14     AKT1         0.0        1.0 -0.654972
# 1  G0646L01     380  chr19     AKT2         0.0        1.0 -0.056330
# 2  G0646L01     380   chr1     AKT3         0.0        1.0 -0.093635
# 3  G0646L01     380   chr2      ALK         0.0        1.0 -0.196039
# 4  G0646L01     380  chr17  ALOX12B         0.0        1.0 -0.033452

# %%
#figure sizes
fig, ax = plt.subplots()
fig.set_size_inches(10, 7)

#Data subsetting
data=dfsorted1[(dfsorted1.Feature == 'RNF43') | (dfsorted1.Feature == 'RPA1')| (dfsorted1.Feature == 'ALOX15B')| (dfsorted1.Feature == 'ALOX12B')| (dfsorted1.Feature == 'STK11')| (dfsorted1.Feature == 'SOX9')| (dfsorted1.Feature == 'MCL1')| (dfsorted1.Feature == 'TSC2')| (dfsorted1.Feature == 'SEMA3A')| (dfsorted1.Feature == 'IGF2')]

#Swarnplot
#https://seaborn.pydata.org/generated/seaborn.swarmplot.html
ax = sns.swarmplot(x="Feature", y="Score", data=data, palette="Set2",hue='pSTAT3_705')

#pointplot
#https://seaborn.pydata.org/generated/seaborn.pointplot.html
sns.pointplot(x="Feature", y="Score", data=data,hue='pSTAT3_705',dodge=True, markers=["_","_"],
                   linestyles=["--", "--"],join=False,estimator=mean,color="#bb3f3f",scale=3.5)

#plt.savefig('Top 10 of mean 1.svg')

# %%
fig, ax = plt.subplots()
fig.set_size_inches(10, 7)

data=dfsorted1[(dfsorted1.Feature == 'RNF43') | (dfsorted1.Feature == 'RPA1')| (dfsorted1.Feature == 'ALOX15B')| (dfsorted1.Feature == 'ALOX12B')| (dfsorted1.Feature == 'STK11')| (dfsorted1.Feature == 'SOX9')| (dfsorted1.Feature == 'MCL1')| (dfsorted1.Feature == 'TSC2')| (dfsorted1.Feature == 'SEMA3A')| (dfsorted1.Feature == 'IGF2')]

ax = sns.swarmplot(x="Feature", y="Score", data=data, palette="Set2",hue='pSTAT3_705')
#plt.savefig('Top 10 of mean 1.svg')

# %%
fig, ax = plt.subplots()
fig.set_size_inches(10, 7)

data=dfsorted1[(dfsorted1.Feature == 'RNF43') | (dfsorted1.Feature == 'RPA1')| (dfsorted1.Feature == 'ALOX15B')| (dfsorted1.Feature == 'ALOX12B')| (dfsorted1.Feature == 'STK11')| (dfsorted1.Feature == 'SOX9')| (dfsorted1.Feature == 'MCL1')| (dfsorted1.Feature == 'TSC2')| (dfsorted1.Feature == 'SEMA3A')| (dfsorted1.Feature == 'IGF2')]


sns.pointplot(x="Feature", y="Score", data=data,hue='pSTAT3_705',dodge=True, markers=["_","_"],
                   linestyles=["--", "--"],join=False,estimator=mean,color="#bb3f3f",scale=3.5)

#plt.savefig('Top 10 of mean 1.svg')

# %%
fig, ax = plt.subplots()
fig.set_size_inches(10, 7)

data=dfsorted1[(dfsorted1.Feature == 'RNF43') | (dfsorted1.Feature == 'RPA1')| (dfsorted1.Feature == 'ALOX15B')| (dfsorted1.Feature == 'ALOX12B')| (dfsorted1.Feature == 'STK11')| (dfsorted1.Feature == 'SOX9')| (dfsorted1.Feature == 'MCL1')| (dfsorted1.Feature == 'TSC2')| (dfsorted1.Feature == 'SEMA3A')| (dfsorted1.Feature == 'IGF2')]

ax = sns.swarmplot(x="Feature", y="Score", data=data, palette="Set2",hue='pSTAT3_705')
sns.pointplot(x="Feature", y="Score", data=data,hue='pSTAT3_705',dodge=True, markers=["_","_"],
                   linestyles=["--", "--"],join=False,estimator=mean,color="#bb3f3f",scale=3.5)

#plt.savefig('Top 10 of mean 1.svg')
